# %%
import pandas as pd
from pathlib import Path

# %%
df = pd.read_csv("/Users/priyaltripathi/snf2-rnaseq/results/alignment/star/ERR458502_ReadsPerGene.out.tab", sep = "\t", header=None)

# %%
df.set_index([0], inplace=True)

# %%
df.head(11)
# Out:
#                      1       2       3
# 0
# N_unmapped       51851   51851   51851
# N_multimapping  141986  141986  141986
# N_noFeature     113711  816234  875803
# N_ambiguous      89676    4993    4880
# YDL246C              0       0       0
# YDL243C             53      37      16
# YDR387C            166      86      80
# YDL094C             10      10       2
# YDR438W             69      34      35
# YDR523C              7       4       3
# YDR542W              0       0       0
